# %%
import os
import sys
import git
import pathlib

import random

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # use GPU
# Using GPU during inference has deterministic results (same as CPU)

PROJ_ROOT_PATH = pathlib.Path(git.Repo('.', search_parent_directories=True).working_tree_dir)
PROJ_ROOT =  str(PROJ_ROOT_PATH)
if PROJ_ROOT not in sys.path:
    sys.path.append(PROJ_ROOT)

from libs import utils, mnist32_cnn
from libs.constants import model_seeds

# %%
# Limit GPU growth
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
# Prepare dataset
# Combine test and train images together into one dataset
DATASET_PATH = str(pathlib.Path(PROJ_ROOT_PATH / "datasets" / "mnist.npz" ))
(train_images, train_labels), (test_images, test_labels) = mnist.load_data(path=DATASET_PATH)
train_images = train_images.astype(np.float32) / 255.0
test_images = test_images.astype(np.float32) / 255.0  

all_images =np.concatenate([train_images, test_images], axis=0)
all_labels =np.concatenate([train_labels, test_labels], axis=0)
all_images = np.expand_dims(all_images, axis=-1)

# resize the input shape , i.e. old shape: 28, new shape: 32
image_x_size = 32
image_y_size = 32
all_images = tf.image.resize(all_images, [image_x_size, image_y_size])

# %%
model_type = "mnist32-cnn_1024_256_64"
model_seed = model_seeds[0]

# %%
# Get model
model_instance = model_type + "-" + str(model_seed)
dataset, model_arch, model_config, layer_widths, seed = utils.instancename2metadata(model_instance)
model_meta_type, model_type, model_instance = utils.metadata2instancenames(dataset, model_arch, layer_widths, seed)

model_folder = pathlib.Path(PROJ_ROOT_PATH / "models" / model_meta_type / model_type)
model_filename = model_instance + ".h5"
model_file = pathlib.Path(model_folder/ model_filename)

# %%
images = all_images[0:15]
# image = tf.expand_dims(all_images[0],axis=0)

# %%
# Load model
model = tf.keras.models.load_model(model_file)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 29, 29, 32)        544
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  flatten (Flatten)           (None, 6272)              0
#
#  fc_0 (Dense)                (None, 1024)              6423552
#
#  fc_1 (Dense)                (None, 256)               262400
#
#  fc_2 (Dense)                (None, 64)                16448
#
#  op_layer (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 6,703,594
# Trainable params: 6,703,594
# Non-trainable params: 0
# _________________________________________________________________

# %%
conv_out = model.layers[0](images)

# %%
pool_out = model.layers[1](
                model.layers[0](images))

# %%
flat_out = model.layers[2](
                model.layers[1](
                    model.layers[0](images)))

# %%
fc_0_out = model.layers[3](
                model.layers[2](
                    model.layers[1](
                        model.layers[0](images))))

# %%
fc_1_out = model.layers[4](
                model.layers[3](
                  model.layers[2](
                      model.layers[1](
                          model.layers[0](images)))))

# %%
fc_2_out = model.layers[5](
              model.layers[4](
                  model.layers[3](
                      model.layers[2](
                          model.layers[1](
                              model.layers[0](images))))))

# %%
op_layer_out = model.layers[6](
                  model.layers[5](
                      model.layers[4](
                          model.layers[3](
                              model.layers[2](
                                  model.layers[1](
                                      model.layers[0](images)))))))

# %%
tf.reduce_sum(op_layer_out - model(images))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>

# %%
op_layer_out
# Out:
# <tf.Tensor: shape=(15, 10), dtype=float32, numpy=
# array([[2.71675174e-12, 3.35802480e-12, 6.55135043e-11, 1.64698791e-02,
#         2.62287544e-12, 9.83529866e-01, 8.16055348e-11, 4.47783616e-11,
#         1.03576543e-08, 1.78205411e-07],
#        [9.99990821e-01, 9.73690589e-07, 7.60873536e-06, 2.72391198e-09,
#         2.23365770e-08, 1.08090892e-09, 1.82814304e-07, 1.20004643e-07,
#         6.05420025e-09, 2.56503085e-07],
#        [7.64120074e-08, 1.08786495e-04, 5.45928851e-05, 3.62876762e-07,
#         9.99743521e-01, 1.86826782e-07, 8.30925018e-08, 8.59544234e-05,
#         9.79177344e-08, 6.15908402e-06],
#        [8.56766533e-08, 9.99975681e-01, 2.30086272e-07, 2.04455217e-10,
#         9.00513623e-06, 2.33917081e-08, 4.04213303e-08, 1.45030317e-05,
#         3.65521089e-07, 8.12035150e-09],
#        [1.05059872e-08, 1.07096344e-06, 2.58097552e-05, 3.54660478e-05,
#         1.58940081e-03, 1.93853020e-06, 1.29515912e-10, 1.49401691e-04,
#         1.65589190e-05, 9.98180389e-01],
#        [9.41910816e-09, 6.22012775e-10, 9.99996662e-01, 2.37902867e-07,
#         1.37363415e-07, 5.16455101e-10, 6.10398329e-11, 1.64609969e-06,
#         1.15753085e-06, 1.95067486e-07],
#        [5.54907120e-10, 9.99970675e-01, 1.21149938e-07, 1.16875782e-07,
#         2.20829716e-05, 1.02040183e-07, 1.42079193e-08, 2.92214281e-06,
#         3.90718742e-06, 5.36963789e-08],
#        [1.78494359e-13, 2.27014655e-13, 1.44159817e-09, 1.00000000e+00,
#         3.28178614e-17, 8.93007834e-10, 9.67270928e-18, 3.14829274e-11,
#         1.61206817e-08, 3.32992300e-08],
#        [8.49258939e-08, 9.99498129e-01, 5.12261465e-07, 3.05214513e-07,
#         3.73119692e-04, 1.68788142e-06, 3.11747073e-07, 1.16235075e-04,
#         7.08917469e-06, 2.38533448e-06],
#        [3.64674122e-07, 5.06731013e-08, 3.88302823e-07, 3.44811596e-10,
#         9.99996185e-01, 1.83891880e-09, 6.44078000e-08, 2.92459276e-06,
#         1.34759883e-08, 4.87501983e-10],
#        [2.70615856e-11, 4.82323959e-10, 2.08454076e-09, 9.99995112e-01,
#         4.95228988e-12, 4.11091423e-06, 9.11785906e-14, 5.31263956e-11,
#         1.27103625e-08, 8.06130458e-07],
#        [6.31401690e-06, 2.29983334e-06, 5.68533369e-06, 3.71544411e-05,
#         8.91105856e-07, 9.99506831e-01, 2.87799048e-04, 2.17769798e-06,
#         1.45136422e-04, 5.71621922e-06],
#        [2.52359603e-17, 7.97500684e-16, 2.80880289e-12, 1.00000000e+00,
#         1.58309234e-17, 9.89986010e-11, 5.27411153e-17, 2.84604256e-14,
#         2.53547253e-11, 2.44341331e-12],
#        [3.03421928e-08, 2.17649107e-10, 5.12804188e-10, 2.00697237e-09,
#         2.55772612e-08, 2.95864623e-07, 9.99999523e-01, 6.48724477e-12,
#         1.37393926e-07, 5.62026869e-10],
#        [9.95258276e-08, 9.99702275e-01, 1.14384807e-06, 3.99586327e-07,
#         1.09029301e-04, 8.18650904e-07, 7.98690792e-07, 1.69609979e-04,
#         1.51551221e-05, 5.48179344e-07]], dtype=float32)>

# %%
fc_2_out
# Out:
# <tf.Tensor: shape=(15, 64), dtype=float32, numpy=
# array([[ 0.        ,  0.        ,  7.029243  ,  0.5471495 ,  2.5350912 ,
#          1.6151757 ,  4.0116043 ,  0.        ,  5.3669305 ,  0.        ,
#          3.7226794 , 10.914504  ,  2.089747  ,  0.        ,  0.        ,
#          1.9117383 ,  6.807363  ,  7.7262974 ,  4.6767454 ,  0.        ,
#          0.        ,  0.        ,  2.291761  ,  6.2492948 ,  5.335433  ,
#          7.646982  ,  0.        ,  8.407822  ,  6.723912  ,  0.        ,
#          7.404195  ,  0.02817028,  0.        ,  5.5928273 ,  4.4628625 ,
#          0.        ,  8.510649  ,  1.3339181 ,  3.145214  ,  0.        ,
#          0.9278116 ,  7.222084  ,  3.2029016 ,  0.        ,  1.6681744 ,
#          0.        ,  0.        ,  1.315224  ,  5.17088   ,  8.520081  ,
#          0.        ,  3.4152188 ,  1.2961205 ,  3.1464596 ,  0.        ,
#          4.2674    ,  2.1508512 ,  4.743614  ,  0.        ,  1.8361688 ,
#          9.36847   ,  6.500458  ,  4.6127214 ,  4.4707108 ],
#        [ 2.7214854 ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  1.3098792 ,  5.8547897 ,  1.8778032 ,  1.2443632 ,
#          2.331463  ,  2.871293  , 10.753847  ,  1.3843907 ,  0.        ,
#         11.034116  ,  3.5623581 ,  2.0044181 ,  0.3359324 ,  0.        ,
#          0.        ,  0.        ,  4.6496263 ,  7.5014787 ,  2.7249968 ,
#          0.        ,  2.7185817 ,  0.        ,  1.2504765 ,  0.        ,
#          6.6060333 ,  3.106641  ,  0.        ,  0.86955655,  7.6189904 ,
#          0.        ,  1.5450716 ,  0.62033296,  1.5572617 ,  0.        ,
#          0.11507329,  6.8728194 ,  0.        ,  0.        ,  4.47465   ,
#          0.        ,  0.6796837 ,  0.        ,  0.27839655,  4.613226  ,
#          0.        ,  0.        ,  5.1813836 ,  1.709585  ,  2.732882  ,
#          6.4293346 ,  2.3808775 ,  2.32774   ,  0.        ,  1.2312355 ,
#          2.1238518 ,  4.5207577 ,  6.8128457 ,  0.08319379],
#        [ 7.6058497 ,  0.        ,  2.4599981 ,  2.4221885 ,  3.345622  ,
#          0.        ,  2.4778705 ,  0.        ,  5.4287143 ,  4.0824366 ,
#          4.7639427 ,  0.        ,  5.6077175 ,  1.6609929 ,  0.        ,
#          3.2534344 ,  0.18156531,  0.        ,  2.018242  ,  0.        ,
#          0.9602334 ,  3.209144  ,  0.18646915,  4.953825  ,  2.7859867 ,
#          3.1115987 ,  0.        ,  0.        ,  1.2439109 ,  3.9679635 ,
#          6.434155  ,  1.2538335 ,  2.2789207 ,  0.        ,  0.7159132 ,
#          0.        ,  3.4741871 ,  0.        ,  2.2542899 ,  0.        ,
#          3.6161113 ,  0.        ,  2.6522152 ,  0.        ,  4.498225  ,
#          0.        ,  2.5300403 ,  0.        ,  2.0322692 ,  1.1869383 ,
#          2.33434   ,  0.        ,  0.        ,  0.        ,  0.        ,
#          2.0390885 ,  0.25856265,  3.254795  ,  0.        ,  0.4405528 ,
#          2.619419  ,  2.2795248 ,  0.        ,  3.7359092 ],
#        [ 6.157528  ,  0.        ,  0.86231637,  3.2067554 ,  1.961346  ,
#          0.        ,  2.5934258 ,  0.        ,  2.297931  ,  0.48977748,
#          0.2283854 ,  0.13152869,  5.104635  ,  4.5343757 ,  0.        ,
#          6.8135676 ,  0.9683943 ,  0.        ,  2.2383661 ,  0.        ,
#          0.59628266,  3.6270673 ,  0.        ,  4.696187  ,  4.6426587 ,
#          3.4711156 ,  0.        ,  0.        ,  3.8168721 ,  4.7270584 ,
#          2.1212633 ,  1.1732936 ,  0.        ,  3.269855  ,  6.1165943 ,
#          0.        ,  0.4291271 ,  0.        ,  4.244723  ,  0.        ,
#          0.03784029,  0.        ,  0.        ,  0.        ,  3.9125373 ,
#          0.        ,  0.        ,  2.3919713 ,  5.6175456 ,  2.4621804 ,
#          5.2140546 ,  0.56328917,  0.8538551 ,  0.22287284,  0.        ,
#          2.5357492 ,  3.192604  ,  6.8182344 ,  0.        ,  0.        ,
#          2.8629177 ,  5.5862417 ,  0.        ,  0.6362205 ],
#        [ 5.914026  ,  0.        ,  8.404374  ,  1.5541594 ,  3.5213532 ,
#          0.        ,  7.159317  ,  2.0451384 ,  7.6254067 ,  4.518783  ,
#          4.4567385 ,  0.22459061,  7.285503  ,  2.3345895 ,  0.        ,
#          3.5726192 ,  0.4023243 ,  1.4162992 ,  4.159539  ,  0.        ,
#          0.4638046 ,  3.8335896 ,  4.056093  ,  7.4568505 ,  0.9644053 ,
#          8.012066  ,  0.        ,  0.        ,  2.131833  ,  0.7334119 ,
#          7.772324  ,  1.0149407 ,  2.3969078 ,  0.        ,  0.7138561 ,
#          0.        ,  6.9957814 ,  5.645785  ,  2.292182  ,  0.        ,
#          3.7537673 ,  0.        ,  3.6919413 ,  0.        ,  3.3636346 ,
#          0.        ,  0.9969266 ,  0.7203601 ,  0.5399108 ,  4.9106517 ,
#          5.6419153 ,  4.5671825 ,  3.3541925 ,  0.        ,  0.        ,
#          6.272246  ,  1.1958036 ,  5.352772  ,  0.        ,  0.        ,
#          5.533576  ,  4.043054  ,  0.44190496,  4.2510796 ],
#        [ 2.3271945 ,  0.        ,  7.7787247 ,  2.8275642 ,  0.3777799 ,
#          0.        ,  3.6123734 ,  0.        ,  7.7442775 ,  1.6186073 ,
#          4.062535  ,  4.574343  ,  7.674782  ,  0.        ,  0.        ,
#          8.065099  ,  0.        ,  1.4228584 ,  1.8890237 ,  0.        ,
#          1.846129  ,  1.9584807 ,  1.4659251 ,  4.4171295 ,  1.8529592 ,
#          6.9779763 ,  0.        ,  0.        ,  2.4137337 ,  0.        ,
#         13.033684  ,  3.806446  ,  0.        ,  0.24691923,  4.449739  ,
#          0.        ,  7.3486977 ,  0.        ,  2.277258  ,  0.        ,
#          2.7441626 ,  2.4486136 ,  0.        ,  0.        ,  5.9327583 ,
#          0.        ,  0.08450039,  4.151879  ,  7.3922    ,  4.542694  ,
#          0.1341876 ,  0.        ,  1.4723772 ,  0.        ,  0.        ,
#          5.8663244 ,  3.2257633 ,  3.6349287 ,  0.        ,  0.        ,
#          3.9535782 ,  7.6214585 ,  5.4944673 ,  4.174342  ],
#        [ 7.980145  ,  0.        ,  2.7465656 ,  0.        ,  3.3918004 ,
#          0.        ,  7.510102  ,  0.        ,  4.4717426 ,  0.2862471 ,
#          1.571686  ,  1.930992  ,  3.802943  ,  3.363137  ,  0.        ,
#          5.8752475 ,  1.8628232 ,  0.94412607,  3.2581425 ,  0.        ,
#          0.        ,  1.1711221 ,  1.6453441 ,  0.        ,  6.9434643 ,
#          4.8974776 ,  0.        ,  0.        ,  6.251376  ,  6.0808487 ,
#          1.8813722 ,  0.        ,  0.        ,  2.9687285 ,  7.248859  ,
#          0.        ,  1.7211587 ,  0.        ,  3.077301  ,  0.        ,
#          1.673191  ,  0.        ,  0.        ,  0.        ,  3.90949   ,
#          0.        ,  0.        ,  1.5546341 ,  5.772524  ,  3.530691  ,
#          0.        ,  0.        ,  0.        ,  2.0898285 ,  0.        ,
#          2.7430773 ,  1.6879047 ,  6.3744698 ,  0.        ,  0.9245762 ,
#          4.224543  ,  5.646102  ,  0.7528582 ,  4.274437  ],
#        [ 0.98748475,  0.        ,  8.556587  ,  0.53749764,  4.939615  ,
#          0.24392089,  6.91025   ,  0.        ,  6.8452067 ,  0.        ,
#          6.2037587 ,  6.8474636 ,  3.128677  ,  0.40661424,  0.        ,
#          3.285835  ,  4.3019037 ,  3.796162  ,  3.3592324 ,  0.        ,
#          5.109961  ,  0.        ,  4.3791685 ,  5.934394  ,  5.3971624 ,
#         10.97369   ,  0.        ,  6.719018  ,  5.7956266 ,  0.        ,
#          7.41378   ,  5.435421  ,  0.        ,  4.500932  ,  2.2692816 ,
#          0.        ,  9.982244  ,  0.        ,  2.184593  ,  0.        ,
#          0.        ,  3.5591536 ,  0.        ,  0.        ,  0.9942362 ,
#          0.        ,  0.        ,  2.3809698 ,  7.86927   , 13.880676  ,
#          3.778215  ,  3.8849802 ,  5.034954  ,  2.313136  ,  0.41032505,
#          8.616032  ,  4.5992393 ,  6.454514  ,  0.        ,  0.        ,
#          8.879837  ,  7.480375  ,  8.145463  ,  1.036544  ],
#        [ 6.0885186 ,  0.        ,  0.9626496 ,  0.        ,  1.6061628 ,
#          0.        ,  5.7575746 ,  0.28753334,  3.9466677 ,  0.51183236,
#          0.8826463 ,  0.94152975,  3.5369973 ,  2.467552  ,  0.        ,
#          4.82592   ,  1.8132786 ,  0.7276529 ,  2.0358443 ,  0.        ,
#          0.        ,  0.9435582 ,  1.5366828 ,  0.31076944,  5.190047  ,
#          3.0813727 ,  0.        ,  0.        ,  4.7155924 ,  4.913993  ,
#          0.6346004 ,  0.        ,  0.        ,  2.208548  ,  5.040977  ,
#          0.        ,  1.0864968 ,  0.        ,  1.6179508 ,  0.        ,
#          1.3228393 ,  0.        ,  0.        ,  0.        ,  2.6605983 ,
#          0.        ,  0.        ,  0.7241045 ,  3.1045713 ,  1.3684654 ,
#          0.        ,  0.        ,  0.        ,  1.1504897 ,  0.        ,
#          1.7581186 ,  1.5642228 ,  5.255428  ,  0.        ,  0.9204881 ,
#          2.7975135 ,  4.383334  ,  0.        ,  3.392881  ],
#        [ 8.707825  ,  0.        ,  4.278631  ,  0.85134035,  0.24556436,
#          0.        ,  4.808238  ,  3.0047503 ,  5.3804216 ,  5.410342  ,
#          4.6040072 ,  1.1272135 ,  8.967013  ,  2.3237169 ,  0.        ,
#          5.2803583 ,  0.95794564,  0.        ,  2.9683125 ,  0.        ,
#          2.067971  ,  4.790697  ,  2.3235064 ,  9.845501  ,  2.1011758 ,
#          4.6289797 ,  0.        ,  0.        ,  0.5593667 ,  3.7824574 ,
#         11.402515  ,  1.2948551 ,  2.0283577 ,  0.        ,  6.7864366 ,
#          0.        ,  2.8511782 ,  0.47442415,  5.9524794 ,  0.        ,
#          6.3486433 ,  0.        ,  1.1219071 ,  0.        ,  4.864065  ,
#          0.        ,  2.770421  ,  0.8477909 ,  1.5668979 ,  0.        ,
#          1.0049474 ,  0.18809555,  0.        ,  0.        ,  0.        ,
#          2.0047581 ,  2.6499915 ,  0.61454815,  0.        ,  0.2597339 ,
#          4.6874743 ,  2.312197  ,  0.        ,  3.7050276 ],
#        [ 2.3733356 ,  0.        ,  7.7881184 ,  0.01908543,  3.9332464 ,
#          0.41501233,  6.26465   ,  0.        ,  6.26501   ,  0.        ,
#          2.9849904 ,  8.804752  ,  2.9614954 ,  0.9568803 ,  0.        ,
#          3.2202175 ,  5.7780633 ,  2.200244  ,  3.1413472 ,  0.        ,
#          2.1981628 ,  0.25283858,  4.1138377 ,  4.890413  ,  7.9175    ,
#          8.146689  ,  0.        ,  7.1114016 ,  6.6217384 ,  0.84913635,
#          7.234304  ,  1.7024223 ,  0.        ,  5.5697823 ,  3.3867831 ,
#          0.        ,  8.896478  ,  0.04844181,  2.700545  ,  0.        ,
#          2.5023842 ,  2.1782203 ,  0.41404164,  0.        ,  1.4810355 ,
#          0.        ,  0.        ,  0.29086488,  5.0436287 , 10.412014  ,
#          2.689138  ,  2.1571403 ,  1.4448881 ,  3.0140216 ,  0.        ,
#          5.4967165 ,  3.6247473 ,  6.3044586 ,  0.        ,  0.68500143,
#          8.960616  ,  7.107349  ,  8.45524   ,  3.7343457 ],
#        [ 0.21625493,  0.        ,  3.2615275 ,  0.        ,  1.367763  ,
#          0.        ,  1.6066957 ,  1.8446273 ,  0.1989999 ,  0.        ,
#          0.        ,  6.690426  ,  1.8314589 ,  2.0603578 ,  0.        ,
#          4.15482   ,  1.338562  ,  2.567412  ,  1.5954726 ,  0.        ,
#          2.3344216 ,  4.581612  ,  1.1174636 ,  4.087038  ,  1.36525   ,
#          2.610295  ,  0.11034888,  0.        ,  0.        ,  1.8609998 ,
#          3.883137  ,  1.8704318 ,  0.        ,  4.9552364 ,  4.241043  ,
#          0.        ,  2.9315937 ,  0.98321456,  4.058134  ,  0.        ,
#          0.        ,  4.0656934 ,  1.1284913 ,  0.        ,  1.5466017 ,
#          0.        ,  0.        ,  0.        ,  4.6649637 ,  3.0220542 ,
#          0.        ,  2.1288922 ,  0.9736983 ,  0.        ,  0.        ,
#          2.0774899 ,  0.3095329 ,  1.9756813 ,  0.        ,  2.2325127 ,
#          5.6015325 ,  3.3683062 ,  0.27067304,  3.6042273 ],
#        [ 1.4555725 ,  0.        , 11.689981  ,  2.4196105 ,  6.8793592 ,
#          1.4271103 ,  5.382773  ,  0.        ,  8.705386  ,  0.        ,
#          4.794754  ,  8.465524  ,  2.7159183 ,  0.        ,  0.        ,
#          1.6269004 ,  2.863914  ,  3.7033641 ,  6.102441  ,  0.        ,
#          1.2148224 ,  0.3229867 ,  5.55782   ,  3.878728  ,  7.7608147 ,
#          9.099217  ,  0.        , 10.397831  , 10.614341  ,  0.3789481 ,
#         11.050216  ,  0.        ,  0.        ,  5.0064096 ,  2.40273   ,
#          0.        , 10.050351  ,  0.        ,  2.408424  ,  0.        ,
#          3.00221   ,  3.0029607 ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.41355246,  9.228734  , 10.685704  ,
#          0.01439371,  2.106463  ,  0.        ,  5.85928   ,  0.        ,
#          6.155674  ,  3.2105289 ,  4.017607  ,  0.        ,  0.92911816,
#          6.929756  ,  4.7712283 ,  8.875727  ,  0.2765703 ],
#        [ 5.897383  ,  0.        ,  7.4156904 ,  0.5112861 ,  1.3077458 ,
#          0.        ,  1.0501443 ,  5.8356814 ,  0.03380321,  2.6213331 ,
#          2.470075  ,  7.034041  ,  7.7487473 ,  3.3649714 ,  0.        ,
#          9.188626  ,  3.0443633 ,  6.7860093 ,  4.387513  ,  0.        ,
#          0.7038029 ,  2.4742436 ,  8.964218  ,  7.746667  ,  1.2711533 ,
#          1.1631106 ,  0.        ,  0.        ,  0.        ,  0.5561089 ,
#         13.80894   ,  2.469778  ,  1.0263453 ,  2.9098165 ,  7.7241426 ,
#          0.        ,  1.0757563 ,  0.        ,  6.2287273 ,  0.        ,
#          1.7662877 ,  0.5544252 ,  2.3847003 ,  0.        ,  4.853226  ,
#          0.        ,  4.5235615 ,  0.        ,  5.7318745 ,  0.4909887 ,
#          0.        ,  0.8015749 ,  0.        ,  0.        ,  0.        ,
#          0.5245645 ,  1.2220224 ,  0.        ,  0.        ,  6.4338307 ,
#          6.896105  ,  0.        ,  0.        ,  3.1800525 ],
#        [ 6.5000124 ,  0.        ,  1.4821708 ,  0.        ,  2.0602016 ,
#          0.        ,  5.7985964 ,  1.0135032 ,  3.720355  ,  0.78728974,
#          1.0408573 ,  0.8277272 ,  3.2510104 ,  2.6642654 ,  0.        ,
#          5.561486  ,  1.3262315 ,  1.129887  ,  1.7279822 ,  0.        ,
#          0.        ,  1.4471524 ,  1.3619999 ,  0.77022314,  5.0385795 ,
#          3.1904984 ,  0.        ,  0.        ,  4.8315177 ,  4.755076  ,
#          1.675317  ,  0.        ,  0.        ,  2.8719692 ,  5.8242135 ,
#          0.        ,  0.55050945,  0.        ,  1.67429   ,  0.        ,
#          0.9996579 ,  0.        ,  0.        ,  0.        ,  2.6440458 ,
#          0.        ,  0.        ,  1.3431352 ,  4.210692  ,  1.4251317 ,
#          0.        ,  0.        ,  0.        ,  1.7160096 ,  0.        ,
#          2.2330275 ,  1.6358558 ,  4.524099  ,  0.        ,  0.8936928 ,
#          2.3124747 ,  4.349276  ,  0.05739696,  2.0192437 ]],
#       dtype=float32)>
